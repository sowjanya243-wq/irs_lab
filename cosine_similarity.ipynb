# %% [markdown]
# <a href="https://colab.research.google.com/github/sowjanya243-wq/irs_lab/blob/main/cosine_similarity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
d1="Vishnu Institute Of Technology Bhimavaram"
d2="Sri Vishnu Womens College"

# %%
vectorize=TfidfVectorizer()

# %%
vector=vectorize.fit_transform([d1,d2])

# %%
similarity=cosine_similarity(vector[0],vector[1])

# %%
print("cosine similarity is :",similarity)
# Out:
# cosine similarity is : [[0.12735953]]
